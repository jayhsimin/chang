# %%
import shutil
import os
from os import walk
from os.path import join

# %%
img_dir=r'I:\noThresh'
fileList=os.listdir(img_dir)

# %%
for i in fileList:
    oldname=os.path.join(img_dir+'/'+i)
    if i.split('.')[-1] == 'bmp':
        num1 = i.split('.')[0]
        num2 = i.split('.')[1]
        print(num1)
        newname=os.path.join(img_dir+'/'+num1+'.bmp')
        os.rename(oldname, newname)
# Out:
# 7_1141090-5_20181220_OCT_1
# 7_1141090-5_20181220_OCT_2
# 7_1150582-1_20190214_OCT_2
# 7_115957-5_20170919_OCT_2
# 7_1172576-1_20170620_OCT_1
# 7_1172576-1_20170822_OCT_1
# 7_1172576-1_20170919_OCT_1
# 7_1172576-1_20170919_OCT_2
# 7_1172576-1_20171024_OCT_1
# 7_1172576-1_20171024_OCT_2
# 7_1172576-1_20171219_OCT_1
# 7_1215805-3_20180205_OCT_2
# 7_1215805-3_20180305_OCT_2
# 7_1240806-9_20170612_OCT_2
# 7_1240806-9_20170918_OCT_2
# 7_1240806-9_20171016_OCT_2
# 7_1240806-9_20180305_OCT_1
# 7_1244610-5_20161122_OCT_2
# 7_1244610-5_20170221_OCT_2
# 7_1244610-5_20170516_OCT_2
# 7_1244610-5_20170822_OCT_2
# 7_1244610-5_20171121_OCT_2
# 7_1244610-5_20171219_OCT_2
# 7_1288679-2_20190617_OCT_2
# 7_1296950-5_20160815_OCT_2
# 7_1296950-5_20161031_OCT_2
# 7_1296950-5_20170327_OCT_2
# 7_1296950-5_20170522_OCT_1
# 7_1296950-5_20170814_OCT_1
# 7_1296950-5_20170919_OCT_1
# 7_1296950-5_20170919_OCT_2
# 7_1296950-5_20171120_OCT_1
# 7_1296950-5_20180122_OCT_1
# 7_1323372-2_20171207_OCT_2
# ...

# %%
for i in fileList:
    oldname=os.path.join(img_dir+'/'+i)
    if i.split('.')[-1] == 'png':
        num1 = i.split('_')[0]
        newname=os.path.join(img_dir+'/'+num1+'.bmp')
        os.rename(oldname, newname)

# %%
for i in fileList:
    oldname=os.path.join(img_dir+'/'+i)
    if i.split('.')[-1] == 'bmp':
        num1 = i.split('_')[0]
        num2 = i.split('_')[1]
        num3 = i.split('_')[2]
        num4 = i.split('_')[3]
        num5 = i.split('_')[4]
        print(num5)
        #newname=os.path.join(img_dir+'/'+num1+"_"+num2+"_"+num3+"_"+num4'.bmp')
        #os.rename(oldname, newname)
